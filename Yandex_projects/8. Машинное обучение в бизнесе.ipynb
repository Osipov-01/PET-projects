# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b><br>
#
# Проект выполнен отлично!) Критичных ошибок нет. Отправляю тебе обратно на случай, если остались вопросы)) Если вопросов нет, возвращай обратно и я сразу приму проект 😊
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Ответный комментарий:</b> Доброго времени суток, Ирина! (Не знаю, во сколько прочтёшь мой комментарий) Вопросов нет. Спасибо за замечания, особенно, мне понравилось, где ты добавила свою ячейку и показала другой способ через scipy.stats.percentileofscore, как рассчитать %  скважин, превышающих безубыточный объем. Ну и благодарность за дополнительные литературу и ссылки на видео:) <br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b><br>
#
# Иван, спасибо за обратную связь) Для меня это важно. Искренне рада, что мои советы пригодились :)
#
# </div>

# %% [markdown]
# Иван, привет! Меня зовут Ирина. Сегодня я проверю твой проект.<br>
# <br> Ты можешь обращаться ко мне на "ты"😏 Надеюсь, ты не будешь против, если и я буду обращаться к тебе на "ты". Но если для тебя это неприемлeмо, дай знать, пожалуйста) <br>
# <br> Мне очень важна твоя реакция на мои комментарии, особенно <font color='red'>красные</font>. Можешь реагировать, например, так ('исправлено', ...)<br>
# <br> Ты можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. <br>
# Это нужно, чтобы не создавалась путаница😉<br>
# Например, так:<br>
#
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Были внесены следующие изменения ...<br></div>
#
#
# <br> Пожалуйста, не удаляй мои комментарии, так как они повышают качество повторного ревью и делают его быстрее)<br>
# <br> Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓<br>
#
# Для твоего удобства мои комментарии будут в <font color='green'>зеленой</font>, <font color='orange'>желтой</font> или <font color='red'>красной</font> рамках:<br>
# <br>
#
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <b>Ошибка:</b><br>
# Если требуются исправления. Работа не может быть принята с красными комментариями.<br></div>
#
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Если можно немного улучшить.<br></div>
#
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# Если все сделано отлично.<br></div>

# %% [markdown]
# # Выбор локации для скважины

# %% [markdown]
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.
#
# Вам предоставлены пробы нефти в трёх регионах: в каждом 10 000 месторождений, где измерили качество нефти и объём её запасов. Постройте модель машинного обучения, которая поможет определить регион, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой *Bootstrap.*
#
# Шаги для выбора локации:
#
# - В избранном регионе ищут месторождения, для каждого определяют значения признаков;
# - Строят модель и оценивают объём запасов;
# - Выбирают месторождения с самым высокими оценками значений. Количество месторождений зависит от бюджета компании и стоимости разработки одной скважины;
# - Прибыль равна суммарной прибыли отобранных месторождений.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍 Есть введение в проект. Отлично!<br>
#
# </div>

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# ![2023-04-23_11-46-30.png](attachment:2023-04-23_11-46-30.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# У тебя ячейки начинались не с первой. Я проверила - есть код работает. Но лучше перед отправкой проекта проверять работоспособность кода - это можно сделать, нажав на панели Jupiter Hub 👉 **Kernel** 👉  **Restart & Run All** .<br>
# Потом обязательно сохрани. Для этого сделай так: 👉  **File**  👉   **Save and Checkpoint** .
# Когда сохранишь, пожалуйста, проверь - обрати внимание на сообщение "**Последняя контрольная точка: несколько секунд назад
# (автосохранение)**" <br>
# </div>

# %% [markdown]
# ![2022-06-25_09-17-28.png](attachment:2022-06-25_09-17-28.png)

# %% [markdown]
# ![2022-06-26_15-59-11.png](attachment:2022-06-26_15-59-11.png)

# %% [markdown]
# Импорт необходимых библиотек для работы с данными

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import numpy as np

state = np.random.RandomState(12345)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Здорово, что импортируешь необходимые библиотеки в первой ячейке. Так сразу понятно какие используются библиотеки и можно легко настроить свое окружение при необходимости.
# </div>

# %% [markdown]
# Чтение данных

# %%
df1 = pd.read_csv('/datasets/geo_data_0.csv')
df2 = pd.read_csv('/datasets/geo_data_1.csv')
df3 = pd.read_csv('/datasets/geo_data_2.csv')

# %% [markdown]
# Вывод информации, что из себя представляют данные

# %%
display(df1.info())
display(df2.info())
display(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
display(df1.head())
display(df2.head())
display(df3.head())
# Out:
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647
#       id         f0         f1        f2     product
# 0  kBEdx -15.001348  -8.276000 -0.005876    3.179103
# 1  62mP7  14.272088  -3.475083  0.999183   26.953261
# 2  vyE1P   6.263187  -5.948386  5.001160  134.766305
# 3  KcrkZ -13.081196 -11.506057  4.999415  137.945408
# 4  AHL4O  12.702195  -8.147433  5.004363  134.766305
#       id        f0        f1        f2     product
# 0  fwXo0 -1.146987  0.963328 -0.828965   27.758673
# 1  WJtFt  0.262778  0.269839 -2.530187   56.069697
# 2  ovLUW  0.194587  0.289035 -5.586433   62.871910
# 3  q6cA6  2.236060 -0.553760  0.930038  114.572842
# 4  WPMUX -0.515993  1.716266  5.899011  149.600746

# %% [markdown]
# Проверим данные на дубликаты

# %%
print('Кол-во дубликатов в таблице №1:', df1.duplicated().sum())
print('Кол-во дубликатов в таблице №2:', df2.duplicated().sum())
print('Кол-во дубликатов в таблице №3:', df3.duplicated().sum())
# Out:
# Кол-во дубликатов в таблице №1: 0
# Кол-во дубликатов в таблице №2: 0
# Кол-во дубликатов в таблице №3: 0

# %% [markdown]
# Изучим данные на выбросы

# %%
def out_boxplot(dfs, columns):
    count_df = len(dfs)
    count_columns = len(columns)
    fig, axs = plt.subplots(nrows= count_df, ncols= count_columns, figsize = (20,15))
    for row in range(count_df):
         for column in range(count_columns):
            axs[row][column].boxplot(x=columns[column], data=dfs[row])
            axs[0][column].set_xlabel(columns[column])
            axs[row][0].set_ylabel(f'df{row+1}')

# %%
columns = df1.columns.tolist()
columns.remove('id')
dfs = [df1, df2, df3]

out_boxplot(dfs, columns)

# %% [markdown]
# Диаграмма размаха показала выбросы "чёрные точки за усами" в датафреймах df1 (столбец - f2), df2 (столбец - f1), df3 (столбец - f0, f1, f2)

# %% [markdown]
# Напишем функцию, которая будет возвращать таблицу без выбросов, затем подправим данные с помощью вызова этой самой функции

# %%
def df_process(df, columns):
    df_processed = df
    for column in columns:
        q25 = df_processed[column].quantile(.25)
        q75 = df_processed[column].quantile(.75)        
        q_min = q25 - 1.5*(q75-q25)
        q_max = q75 + 1.5*(q75-q25)
        df_processed = df_processed[df_processed[column] >= q_min]
        df_processed = df_processed[df_processed[column] <= q_max]
    return df_processed

# %%
columns = df1.columns.tolist()
columns.remove('id')
df1 = df_process(df1, ['f2']).reset_index(drop=True)
df2 = df_process(df2, ['f1']).reset_index(drop=True)
df3 = df_process(df3, ['f0', 'f1', 'f2']).reset_index(drop=True)
print(f'Кол-во оставшихся строк df1 - {df1.shape[0]}, удалено - {100000 - df1.shape[0]}')
print(f'Кол-во оставшихся строк df2 - {df2.shape[0]}, удалено - {100000 - df2.shape[0]}')
print(f'Кол-во оставшихся строк df3 - {df3.shape[0]}, удалено - {100000 - df3.shape[0]}')
# Out:
# Кол-во оставшихся строк df1 - 99494, удалено - 506
# Кол-во оставшихся строк df2 - 99364, удалено - 636
# Кол-во оставшихся строк df3 - 98003, удалено - 1997

# %% [markdown]
# Проверим, что получилось, снова вызвав функцию вывода диаграмм размаха

# %%
columns = df1.columns.tolist()
columns.remove('id')
dfs = [df1, df2, df3]

out_boxplot(dfs, columns)

# %% [markdown]
# Видим, что выбросов в данных уже отсутствуют

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Хорошее решение - очистить данные от выбросов.
# * Выброс – это наблюдение, удаленное от других в выборке. Другими словами, это наблюдение, которое расходится с общей закономерностью выборки. Алгоритмы Машинного обучения чувствительны к диапазону и распределению значений атрибутов. Выбросы могут ввести в заблуждение Модель, что приведет к увеличению времени обучения, меньшей Точности и, в итоге, к худшим результатам.
# </div>

# %% [markdown]
# Также можем определить, как столбцы в таблицах df1, df2, df3 зависят друг от друга, где положительные значения показывают прямую зависимость, отрицательные - обратную

# %%
for df in dfs:
    display(df.corr())
# Out:
#                f0        f1        f2   product
# f0       1.000000 -0.440716 -0.003339  0.143591
# f1      -0.440716  1.000000  0.001098 -0.192748
# f2      -0.003339  0.001098  1.000000  0.480159
# product  0.143591 -0.192748  0.480159  1.000000
#                f0        f1        f2   product
# f0       1.000000  0.178877 -0.001670 -0.030389
# f1       0.178877  1.000000 -0.002756 -0.010174
# f2      -0.001670 -0.002756  1.000000  0.999397
# product -0.030389 -0.010174  0.999397  1.000000
#                f0        f1        f2   product
# f0       1.000000  0.000649  0.000473 -0.002962
# f1       0.000649  1.000000  0.000710 -0.000895
# f2       0.000473  0.000710  1.000000  0.441211
# product -0.002962 -0.000895  0.441211  1.000000

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
#
#
#
# Для удобной визуализации можно использовать - ["Тепловая карта корреляции".](https://www.delftstack.com/ru/howto/seaborn/correlation-heatplot-seaborn-python/) <br>
# </div>

# %% [markdown]
# Смущают показания в таблице df2, а именно зависимость между столбцами 'f2' и 'product', они почти идентичны, следовательно, можем удалить столбец 'f2'

# %%
df2_first = df2
df2 = df2.drop(['f2'], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Мультиколлинеарность — явление, при котором наблюдается сильная корреляция между **признаками**, что может негативно отразиться на модели.  А здесь признак `f2` коррелирует с целевой переменной `product`, а не с другим признаком, этот факт как раз в пользу более точных предсказаний:) Поэтому `f2` удалять не надо)<br>
#
# Здесь должен был быть красный комментарий, но дальше используешь `dfs`, где не удален `f2`, поэтому следующие вычисления корректные. <br>
#
# Рекомендую посмотреть отрывок из курса Статистики - ["Корреляция и регрессия".](https://stepik.org/lesson/8086/step/1?unit=1365) <br>
# </div>

# %% [markdown]
# **Вывод:** данные обработаны и подготовлены для дальнейшего анализа; в ходе этого процесса были обнаружены выбросы в данные, которые были исправлены; проверка на дубликаты и типы данных прошла успешно; в ходе корреляции данных в таблице df2 был удалён столбец 'f2', т.к. значение было очень близко к 1

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Очень хорошо, что не забываешь проводить разведочный анализ данных. Чем лучше знаем набор данных, тем лучше можем его использовать!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Еще можно проверить дубликаты по `id`
# </div>

# %% [markdown]
# ## Обучение и проверка модели

# %% [markdown]
# По условию проекта, в данном разделе нужно обучить и проверить модель для каждого региона

# %%
models = []
products_mean = []
RMSE_s = []
predicted_valid_s = []

features_train_s = []
features_valid_s = []
target_train_s = []
target_valid_s = []

# %%
for i in range(len(dfs)):
    features = dfs[i].drop(['product', 'id'], axis=1)
    target = dfs[i]['product']
    features_train, features_valid, target_train, target_valid = (
        train_test_split(features, target, test_size = .25, random_state = state)
    )
    
    #Проведём масштабирование признаков
    scaler = StandardScaler()

    scaler.fit(features_train)

    features_train = scaler.transform(features_train)
    features_valid = scaler.transform(features_valid)
    
    features_train_s.append(features_train)
    features_valid_s.append(features_valid)
    target_train_s.append(target_train)
    target_valid_s.append(target_valid)
    
    #Создадим и обучим модель
    model = LinearRegression()
    model.fit(features_valid, target_valid)
    models.append(model)
    
    #Предсказания
    predicted_valid = model.predict(features_valid)
    predicted_valid_s.append(predicted_valid)
    
    #Средний запас
    product_mean = predicted_valid.mean()
    products_mean.append(product_mean)
    
    #RMSE модели
    RMSE = mean_squared_error(target_valid, predicted_valid)**.5
    RMSE_s.append(RMSE)
    
    print(f'df{i+1}')
    print(f'средний запас предсказанного сырья - {product_mean}')
    print(f'RMSE модели - {RMSE}')
    print('')
# Out:
# df1
# средний запас предсказанного сырья - 92.23780448817918
# RMSE модели - 37.91657629921152
#
# df2
# средний запас предсказанного сырья - 68.77029268370632
# RMSE модели - 0.8904789286386379
#
# df3
# средний запас предсказанного сырья - 94.69140010153471
# RMSE модели - 40.234906334605505

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍
# * Отлично, что зацикливаешь повторяющиеся действия
# *  `id`  - уникальный идентификатор скважины, он не является признаком, поэтому его действительно лучше удалить
# * Данные разделены на обучающую и валидационную выборку корректно - 75:25. Будет надежнее, если после разбиения проверять доли)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b><br>
#
# Очень хорошо, что уделяешь внимание масштабированию, т.к. это влияет на способность модели делать точные прогнозы. Но в этом проекте признаки в одном масштабе) <br>
# Оставлю пару советов, ссылок по этой теме:<br>
# * `StandardScaler` подходит для нормально распределенных данных, в противном случае - `MinMaxScaler`. Здесь статья, которая подробно объясняет разницу [MinMaxScaler() и StandardScaler()](https://vitalflux.com/minmaxscaler-standardscaler-python-examples/)
# * Для `трейна` можно использовать сразу `fit_transform()`. Она объединяет функции: `fit()` и `transform()`.
# * Здесь хороший пример [Когда требуется масштабирование и почему оно важно](https://www.dmitrymakarov.ru/intro/clustering-16/#1-metod-k-srednikh)
# </div>

# %% [markdown]
# **Вывод:**
# Первый регион: по ошибкам на втором месте, по среднему объему запасов регион также на втором месте, но незначительно уступает третьему региону \
# Второй регион:
# Проигрывает другим регионам по объёму запасов, но по показателю средней ошибки лучше всех себя показал \
# Третий регион:
# Самый большой средний объем запасов, но по ошибке регион на последнем месте

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Молодец, что обращаешь внимание на размер ошибки, в двух других регионах она катастрофически большая - почти 40% от  среднего запаса. Если ошибка (RMSE) меньше, значит прогноз точнее и модель лучше обучилась. Если посмотреть корреляцию между признаками и целевой переменной, можно понять почему в одном из регионов ошибка минимальная. Высокий коэффициент корреляции `f2` и целевой переменной говорит о сильной прямой линейной зависимости.
# <br>
# Т.к. при выборе скважин опираемся на предсказания, то качество предсказания имеет огромное значение - важно определить скважины с максимальным запасом.
# </div>

# %% [markdown]
# ## Подготовка к расчёту прибыли

# %% [markdown]
# Сохраним ключевые значения для расчётов в отдельных переменных

# %%
max_points = 500
selected_points = 200
budget_region = 10**10
price_for_every_product = 450000
volume_product = 1000
price_every_burrell = 450
max_per_losses = 0.025

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# * Согласно руководству по написанию кода на Python [PEP-8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html#section-29) названия констант принято задавать заглавными буквами, например, `BUDGET`. А еще важно объявлять их в начале проекта после импортов, затем загрузка данных. Так проще будет их найти и изменить, если возникнет такая необходимость.
# * Для записи больших чисел и более удобного чтения, чтобы не запутаться в нулях, можно использовать такую запись: `450_000` или экспоненциальную запись числа - `45e4`, что означает 45 * 10**4.
# </div>

# %% [markdown]
# Рассчитаем достаточный объём сырья для безубыточной разработки новой скважины и сравним полученный объём сырья со средним запасом в каждом регионе.

# %%
non_losses_products_point = budget_region/(price_for_every_product*volume_product*selected_points)
non_losses_products = non_losses_products_point * volume_product
print(f'Достаточный объём сырья для безубыточной разработки новой скважины - {round(non_losses_products_point, 2)}')
print(f'Минимальное кол-во добычи сырья без убытков - {round(non_losses_products, 2)}')
# Out:
# Достаточный объём сырья для безубыточной разработки новой скважины - 0.11
# Минимальное кол-во добычи сырья без убытков - 111.11

# %% [markdown]
# **КОММЕНТАРИЙ:** непонятна фраза "При нынешних ценах один баррель сырья приносит 450 рублей дохода. Доход с каждой единицы продукта составляет 450 тыс. рублей, поскольку объём указан в тысячах баррелей." Решился при расчёте необходимого объёма сырья для безубыточной разработки скважины умножить в знаменателе величины price_for_every_product и volume_product друг на друга, вроде выходит правильно с точки зрения данных.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b><br>
#
#  Достаточный объём сырья для безубыточной разработки новой скважины - это `10 млрд / 450тыс / 200 точек`.
# </div>

# %% [markdown]
# Посмотрим распределение значений по районам с помощью метода describe

# %%
display('Таблица №1:', df1.describe())
display('Таблица №2:', df2.describe())
display('Таблица №3:', df3.describe())
# Out:
# 'Таблица №1:'
#                  f0            f1            f2       product
# count  99494.000000  99494.000000  99494.000000  99494.000000
# mean       0.500570      0.250044      2.503399     92.500677
# std        0.871838      0.504437      3.181196     44.229330
# min       -1.408605     -0.848218     -6.352956      0.000000
# 25%       -0.072378     -0.201063      0.301496     56.567678
# 50%        0.502606      0.250032      2.516336     91.842533
# 75%        1.073729      0.700574      4.704256    128.517876
# max        2.362331      1.343769     11.353804    185.364347
# 'Таблица №2:'
#                  f0            f1       product
# count  99364.000000  99364.000000  99364.000000
# mean       1.139661     -4.803101     68.809919
# std        8.966349      4.984107     45.934941
# min      -31.609576    -18.667777      0.000000
# 25%       -6.300689     -8.249871     26.953261
# 50%        1.150044     -4.816643     57.085625
# ...

# %% [markdown]
# Можем определить по каждому региону, какой процент скважин содержат больше сырья, чем точка безубыточности

# %%
percents_need = []
for i in range(len(dfs)):
    df_select = dfs[i][dfs[i]['product'] > non_losses_products]
    percent_need = df_select.shape[0]/dfs[i].shape[0]
    percent_need = "{:.0%}".format(percent_need)
    percents_need.append(percent_need)
    print(f'{percent_need} скважин в регионе №{i+1} содержат больше сырья, чем {round(non_losses_products, 2)}')
# Out:
# 37% скважин в регионе №1 содержат больше сырья, чем 111.11
# 17% скважин в регионе №2 содержат больше сырья, чем 111.11
# 38% скважин в регионе №3 содержат больше сырья, чем 111.11

# %%
#ячейка ревьюера

'''можно рассчитать %  скважин, превышающих безубыточный объем, еще так '''
   


from scipy import stats

for i in range(len(dfs)):
    print(100-stats.percentileofscore(dfs[i]["product"], 111))
# Out:
# 36.634369911753474
# 16.518054828710603
# 38.08454843219085

# %% [markdown]
# **Вывод:** достаточный объём сырья для безубыточной разработки новой скважины составляет 111.11 баррелей нефти, что превосходит средний объем запаса в каждом регионе.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b><br>
#
# В каждом регионе средний объем сырья меньше достаточного объёма для безубыточности. Есть 25 000 точек, из которых в результате надо выбрать 200. В результате,  среди этих скважин могут быть скважины с достаточным и недостаточным запасом сырья. <br>
#
# **Главное - выбрать скважины с безубыточным объемом сырья.**  <br>
#
# При выборе скважин **опираемся на предсказания, точность прогноза имеет большое значение**, поэтому перспективнее регион с наиболее точными предсказаниями))
#
#
# </div>

# %% [markdown]
# ## Расчёт прибыли и рисков

# %% [markdown]
# Расчёт прибыли

# %%
def income (target, pred):
    pred_sort = pd.Series(pred).sort_values(ascending=False)
    best_pred_sort = pred_sort[:selected_points]
    best_target_sort = target.reset_index(drop=True)[best_pred_sort.index]
    sum_target = best_target_sort.sum()
    income = sum_target * price_for_every_product - budget_region
    return round(income, 0)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Функция прибыли в порядке.
# </div>

# %%
for i in range(3):
    print(f'Прибыль с 200 лучших скважин в регионе №{i+1} составляет {income(target_valid_s[i], predicted_valid_s[i])} д.е.')
# Out:
# Прибыль с 200 лучших скважин в регионе №1 составляет 3309391799.0 д.е.
# Прибыль с 200 лучших скважин в регионе №2 составляет 2415086697.0 д.е.
# Прибыль с 200 лучших скважин в регионе №3 составляет 2710903408.0 д.е.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b><br>
#
# Было бы здорово знать заранее 200 лучших скважин из 25_000 :) Но по условию задачи можем исследовать только 500 точек.
# </div>

# %% [markdown]
# Расчёт рисков

# %%
def confidence_interval(target, pred):
    incomes = []
    for i in range(1000):
        pred_sample = pd.Series(pred).sample(n = max_points, replace=True, random_state = state)
        incomes.append(income(target, pred_sample))
    incomes = pd.Series(incomes)
    print(f'Средняя прибыль: {incomes.mean()}')
    risk = len(incomes[incomes<0])/len(incomes) 
    print(f'Риски: {"{:.0%}".format(risk)}')
    
    lower = incomes.quantile(0.025)
    upper = incomes.quantile(0.975)    
    
    return lower, upper

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Отлично, что при семплировании данных устанавливаешь `replace = True`, это необходимо чтобы наблюдение в выборку попало несколько раз, что позволяет добиться независимости при каждом выборе, иначе вероятность достать элемент из выборки будет с каждым разом увеличиваться. Чем больше размер подвыборки, тем выраженнее будет зависимость, поэтому без возврата не удастся получить разнообразные варианты, а подвыборку бОльшего размера вообще не получить.
#
# Почему именно так. Вспомним, что выборка - это некоторое представление о генеральной совокупности, ее часть. Значит, что где-то в регионе существуют и другие потенциальные точки добычи нефти, о которых мы можем не знать, но они являются частью этой генеральной совокупности. В этом случае повторяющиеся наблюдения можно считать разными точками добычи из всей генеральной совокупности с близкими характеристиками.
#
# </div>

# %%
for i in range(3):
    print(f'Регион №{i+1}')
    print(f'95%-й доверительный интервал находится м/у {confidence_interval(target_valid_s[i], predicted_valid_s[i])}')
    print('')
# Out:
# Регион №1
# Средняя прибыль: 371943598.787
# Риски: 9%
# 95%-й доверительный интервал находится м/у (-125823998.45, 864935625.875)
#
# Регион №2
# Средняя прибыль: 437676126.663
# Риски: 2%
# 95%-й доверительный интервал находится м/у (36574407.47500001, 831782168.5249999)
#
# Регион №3
# Средняя прибыль: 321589385.669
# Риски: 11%
# 95%-й доверительный интервал находится м/у (-207838879.04999998, 854525741.8249998)

# %% [markdown]
# **Вывод:** Больше всего прибыли с 200 лучших скважин с региона приходится на регион №1, меньше всего - на №2, при этом у региона №2 - самая высокая средняя прибыль из 1000 случайных выборок с 500 рандомными точками, откуда отбираются 200 лучших. Также регион №2 - самый безопасный регион с точки зрения прибыльности (вероятность возникновения рисков убыток: 2%). Регион №2 подходит по условию: вероятность убытков меньше 2.5%, следовательно, этот регион рекомендуется в качестве локации, где можно добывать нефть.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Регион `geo_data_1` выбран абсолютно верно. В этом регионе минимальный % риска, т.к. модель предсказывает хорошо (ошибка минимальная). А при выборе 200 лучших скважин мы опираемся на предсказания, поэтому ничего удивительного  -  регион победил!)
#
# </div>

# %% [markdown]
# <div style="background: #cceeaa; padding: 5px; border: 1px solid green; border-radius: 5px;">
# <font color='green'>
#     <b><u>Общий вывод по проекту</u></b>
# <font color='green'><br>
#
#
# Иван, приложено много усилий, ты - молодец! Крепкий проект! Критичных ошибок нет. Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Что мне особенно понравилось в твоей работе:**:
#
# * Есть разведочный анализ данных.
# * Рассчитан средний запас предсказанного сырья и размер ошибки для каждого региона.
# * Рассчитан достаточный объём сырья для безубыточной разработки новой скважины.
# * Написана функция для расчёта прибыли.
# * Использованы функции для повторяющихся действий.
# * Применена техника `Bootstrap`. Рассчитаны риски, прибыль и доверительный интервал для каждого региона.
# * Есть выводы в каждом блоке.
# * Код логичный и понятный.
# * Проект полностью соответствует плану!<br>
#
# Очень рекомендую посмотреть видео от Глеба Михайлова!)<br>
# **[Линейная Регрессия для Дата Саентиста](https://www.youtube.com/watch?v=QZJ94igWVxQ&t=19s)**     <br>
#
# **Теория и практика в МО - [Сайт Дмитрия Макарова](https://www.dmitrymakarov.ru/)** <br>
#
# **Статья, которая подробно объясняет разницу [MinMaxScaler() и StandardScaler()](https://vitalflux.com/minmaxscaler-standardscaler-python-examples/)** <br>
#
# **Отличное объяснение с примером по [мультиколлинеарности](https://habr.com/ru/company/akbarsdigital/blog/592493/)** <br>
#
# **Интересная статья - [коротко о мультиколлинеарности и что с этим делать](https://medium.com/analytics-vidhya/removing-multi-collinearity-for-linear-and-logistic-regression-f1fa744f3666)** <br>
#
# **Если интересна статистика, можно посмотреть [короткие видео-лекции Карпова на степике](https://stepik.org/lesson/8095/step/1?unit=1371)**    <br>
#
# **Как мне кажется, есть неплохая статья про [смысл техники bootstrap](https://habr.com/ru/company/X5Tech/blog/679842/)**<br>
#
# **Видео-лекция на степике -  [3 раздел - Введение в bootstrap](https://stepik.org/course/2152/syllabus)** <br>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: модели обучены и проверены
#     - [x]  Данные корректно разбиты на обучающую и валидационную выборки
#     - [x]  Модели обучены, предсказания сделаны
#     - [x]  Предсказания и правильные ответы на валидационной выборке сохранены
#     - [x]  На экране напечатаны результаты
#     - [x]  Сделаны выводы
# - [x]  Выполнен шаг 3: проведена подготовка к расчёту прибыли
#     - [x]  Для всех ключевых значений созданы константы Python
#     - [x]  Посчитано минимальное среднее количество продукта в месторождениях региона, достаточное для разработки
#     - [x]  По предыдущему пункту сделаны выводы
#     - [x]  Написана функция расчёта прибыли
# - [x]  Выполнен шаг 4: посчитаны риски и прибыль
#     - [x]  Проведена процедура *Bootstrap*
#     - [x]  Все параметры бутстрепа соответствуют условию
#     - [x]  Найдены все нужные величины
#     - [x]  Предложен регион для разработки месторождения
#     - [x]  Выбор региона обоснован
